# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("length_freq.csv", sep=",")
df.plot(x = 'lengths', y = 'freq')
# Out:
# <AxesSubplot:xlabel='lengths'>
