# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("length_freq.csv", sep=",")
df.plot.scatter(x = 'Length [mm]' , y = 'Frequency [GHz]', c='red', title='Resonant Frequencies of CPWs Simulated With HFSS')
# Out:
# <AxesSubplot:title={'center':'Resonant Frequencies of CPWs Simulated With HFSS'}, xlabel='Length [mm]', ylabel='Frequency [GHz]'>
